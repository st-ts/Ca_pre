# %% [markdown]
# Name + description

# %% [markdown]
# ## Load the libraries and data

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from matplotlib import colors
from matplotlib.ticker import PercentFormatter


import cv2

import bokeh.plotting as bpl
import holoviews as hv

from ipyfilechooser import FileChooser

import os
import json

import math

bpl.output_notebook()
hv.notebook_extension('bokeh')
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="f43a0668-f286-458e-aba6-41089caae62e">Loading BokehJS ...</span>
#     </div>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1004'>
#   <div id="f1a007a6-be62-4e6a-b076-f015d73e929c" data-root-id="p1004" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"35ebfdca-8169-4f04-913e-e85d37460875":{"version":"3.3.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1004"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1005","attributes":{"plot_id":"p1004","comm_id":"3692ed1806da47e9a00cf679d8bbe0d9","client_comm_id":"8b1cc131d0504975ac9630ae001a8bad"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"toggle_value1","properties":[{"name":"active_icons","kind":"Any","default":{"type":"map"}},{"name":"options","kind":"Any","default":{"type":"map","entries":[["favorite","heart"]]}},{"name":"value","kind":"Any","default":[]},{"name":"_reactions","kind":"Any","default":[]},{"name":"_base_url","kind":"Any","default":"https://tabler-icons.io/static/tabler-icons/icons/"}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"value","kind":"Any","default":null},{"name":"fill","kind":"Any","default":"none"}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{ ...
#   var render_items = [{"docid":"35ebfdca-8169-4f04-913e-e85d37460875","roots":{"p1004":"f1a007a6-be62-4e6a-b076-f015d73e929c"},"root_ids":["p1004"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#
#
# </div>

# %%
# Create and display a FileChooser widget
fc = FileChooser('D:/behav/')
fc.filter_pattern = '*.csv'
fc.use_dir_icons = True
display(fc)
# Out:
# FileChooser(path='D:\behav', filename='', title='', show_hidden=False, select_desc='Select', change_desc='Chan…

# %%
file_path = fc.selected_path + '\\' + fc.selected_filename
data = pd.read_csv(file_path)
data_licks_L = pd.read_csv(file_path[0:-4] + '_t_licks_L.csv', header = None)
data_licks_R = pd.read_csv(file_path[0:-4] + '_t_licks_R.csv', header = None)

data = data[data['laser_stim_ts']!=0]
data['end_trial'] = data['laser_stim_ts'].shift(-1) 
data['end_trial'].fillna( data['laser_stim_ts'][data.shape[0]-1] + 6000, inplace=True)
data
# Out:
#      missed  laser  choice  free  resp_start_ts  reward_ts  laser_stim_ts  \
# 0         1      1       0     0           7450          0           7113
# 1         1     -1       0     0          10983          0          10646
# 2         1     -1       0     0          14409          0          14074
# 3         1     -1       0     0          18005          0          17668
# 4         1      0       0     0          21550          0          21212
# ..      ...    ...     ...   ...            ...        ...            ...
# 395       0      0      -1     0        1564043    1564417        1563704
# 396       0      0       1     0        1568486    1568815        1568141
# 397       1      1       0     0        1572831          0        1572497
# 398       1      1       0     0        1576346          0        1575997
# 399       0      0       1     0        1579815    1579876        1579481
#
#      end_trial
# 0      10646.0
# 1      14074.0
# 2      17668.0
# 3      21212.0
# 4      24747.0
# ..         ...
# 395  1568141.0
# 396  1572497.0
# 397  1575997.0
# 398  1579481.0
# 399  1585481.0
#
# [400 rows x 8 columns]

# %%
data
# Out:
#      missed  laser  choice  free  resp_start_ts  reward_ts  laser_stim_ts  \
# 0         1      0       0     0           7486          0           7148
# 1         1     -1       0     0          11102          0          10764
# 2         0      0       1     0          14625      14778          14285
# 3         1      0       0     0          18832          0          18498
# 4         1      0       0     0          22332          0          22002
# ..      ...    ...     ...   ...            ...        ...            ...
# 132       1     -1       0     0         452246          0         451900
# 133       1     -1       0     0         455690          0         455345
# 134       0      0      -1     0         459130          0         458783
# 135       1      1       0     0         461976          0         461647
# 136       1      0       0     0         465480          0         465143
#
#      end_trial
# 0      10764.0
# 1      14285.0
# 2      18498.0
# 3      22002.0
# 4      25481.0
# ..         ...
# 132   455345.0
# 133   458783.0
# 134   461647.0
# 135   465143.0
# 136   471143.0
#
# [137 rows x 8 columns]

# %%
def count_licks_in_trial(row, data_licks):
    # Get licks within the start and end time of the trial
    licks_in_trial = len(data_licks[(data_licks[0] >= row['laser_stim_ts']) & 
                                 (data_licks[0] <= row['laser_stim_ts'] + 1500)]) 

    return licks_in_trial


data['num_licks_L'] = data.apply(lambda row: count_licks_in_trial(row, data_licks_L), axis=1)
data['num_licks_R'] = data.apply(lambda row: count_licks_in_trial(row, data_licks_R), axis=1)

data[data['choice']!=0]
# Out:
#      missed  laser  choice  free  resp_start_ts  reward_ts  laser_stim_ts  \
# 5         0      0       1     0          25089      25839          24747
# 12        0      0      -1     0          50865      51084          50528
# 16        0      0       1     0          65593      65655          65265
# 22        0      0       1     0          86992      87048          86655
# 23        0      0      -1     0          91151      91191          90807
# ..      ...    ...     ...   ...            ...        ...            ...
# 392       0      0       1     0        1552220    1552273        1551891
# 393       0      0       1     0        1556260    1556607        1555927
# 395       0      0      -1     0        1564043    1564417        1563704
# 396       0      0       1     0        1568486    1568815        1568141
# 399       0      0       1     0        1579815    1579876        1579481
#
#      end_trial  num_licks_L  num_licks_R
# 5      29558.0            2            0
# 12     54787.0            2            2
# 16     69266.0            1            0
# 22     90807.0            1            1
# 23     94894.0            3            2
# ..         ...          ...          ...
# 392  1555927.0            1            1
# 393  1560227.0            3            2
# 395  1568141.0            2            2
# 396  1572497.0            1            2
# 399  1585481.0            1            1
#
# [203 rows x 10 columns]

# %%
data[data['choice']!=0].shape
# Out:
# (203, 10)

# %%
laser_tags = ['no', 'left', 'right']

# %%
data_las_left = data[(data['laser'] == 1)]
data_las_right = data[data['laser'] == -1]
data_las_no = data[data['laser'] == 0]

# %%
print(np.mean(data_las_left['missed']))
print(np.mean(data_las_right['missed']))
print(np.mean(data_las_no['missed']))
# Out:
# 0.83
# 0.58
# 0.3

# %%
laser_tags = ['no', 'left', 'right']
for laser in [0, 1, -1]:
    laser_name = laser_tags[laser]
    data_las = data[(data['laser'] == laser)]
    print("for " + laser_name + " laser " )
    print("rate missed: " + str(np.mean(data_las['missed']) ) ) 
    data_las_choice = data_las[ (data_las['choice']!=0)]
    print("rate left choice: " + str( (data_las_choice['choice'] == -1).mean() ) )
    print("freq left lick: " + str( (data_las['num_licks_L']).mean() ) )
    print("freq right lick: " + str( (data_las['num_licks_R']).mean() ) )
# Out:
# for no laser
# rate missed: 0.4647887323943662
# rate left choice: 0.4358974358974359
# freq left lick: 0.9859154929577465
# freq right lick: 0.9436619718309859
# for left laser
# rate missed: 0.84375
# rate left choice: 0.8333333333333334
# freq left lick: 0.1875
# freq right lick: 0.25
# for right laser
# rate missed: 0.7352941176470589
# rate left choice: 0.6666666666666666
# freq left lick: 0.11764705882352941
# freq right lick: 0.47058823529411764

# %%
# Assuming 'data', 'data_licks_L', and 'data_licks_R' are your DataFrames
# and they are already loaded

# Filter for trials with laser type 1
laser_type = 1
filtered_data = data[data['laser'] == laser_type]

# Plotting
plt.figure(figsize=(10, 6))

y = 0;

# Create plot with GridSpec
fig = plt.figure(figsize=(12, 6))

for index, row in filtered_data.iterrows():
    # Get the time of laser stimulation
    laser_time = row['laser_stim_ts']
    
    # Find licks within 4000 ms after laser stimulation
    licks_L = data_licks_L[(data_licks_L[0] >= laser_time) & (data_licks_L[0] <= laser_time + 3000)]
    licks_R = data_licks_R[(data_licks_R[0] >= laser_time) & (data_licks_R[0] <= laser_time + 3000)]

    licks_L = licks_L[0].tolist()
    licks_R = licks_R[0].tolist()
    #if len(licks_L) > 0:
    ys_L = [y]*len(licks_L)
    ys_R = [y]*len(licks_R)
    y = y-1
    licks_L = [x - laser_time for x in licks_L]
    licks_R = [x - laser_time for x in licks_R]
    plt.plot(licks_L, ys_L,'|',color = 'b')
    plt.plot(licks_R, ys_R,'|',color = 'r')

plt.show()

# %%
# Assuming 'data', 'data_licks_L', and 'data_licks_R' are your DataFrames
# and they are already loaded

# Filter for trials with laser type 1
laser_type = -1
filtered_data = data[data['laser'] == laser_type]

# Plotting
plt.figure(figsize=(10, 6))

y = 0;

# Create plot with GridSpec
fig = plt.figure(figsize=(12, 6))

for index, row in filtered_data.iterrows():
    # Get the time of laser stimulation
    laser_time = row['laser_stim_ts']
    
    # Find licks within 4000 ms after laser stimulation
    licks_L = data_licks_L[(data_licks_L[0] >= laser_time) & (data_licks_L[0] <= laser_time + 3000)]
    licks_R = data_licks_R[(data_licks_R[0] >= laser_time) & (data_licks_R[0] <= laser_time + 3000)]

    licks_L = licks_L[0].tolist()
    licks_R = licks_R[0].tolist()
    #if len(licks_L) > 0:
    ys_L = [y]*len(licks_L)
    ys_R = [y]*len(licks_R)
    y = y-1
    licks_L = [x - laser_time for x in licks_L]
    licks_R = [x - laser_time for x in licks_R]
    plt.plot(licks_L, ys_L,'|',color = 'b')
    plt.plot(licks_R, ys_R,'|',color = 'r')

plt.show()

# %%
# Assuming 'data', 'data_licks_L', and 'data_licks_R' are your DataFrames
# and they are already loaded

# Filter for trials with laser type 1
laser_type = 0
filtered_data = data[data['laser'] == laser_type]

# Plotting
plt.figure(figsize=(10, 6))

y = 0;

for index, row in filtered_data.iterrows():
    # Get the time of laser stimulation
    laser_time = row['laser_stim_ts']
    
    # Find licks within 4000 ms after laser stimulation
    licks_L = data_licks_L[(data_licks_L[0] >= laser_time+310) & (data_licks_L[0] <= laser_time + 3000)]
    licks_R = data_licks_R[(data_licks_R[0] >= laser_time+310) & (data_licks_R[0] <= laser_time + 3000)]

    licks_L = licks_L[0].tolist()
    licks_R = licks_R[0].tolist()
    #if len(licks_L) > 0:
    ys_L = [y]*len(licks_L)
    ys_R = [y]*len(licks_R)
    y = y-1
    licks_L = [x - laser_time for x in licks_L]
    licks_R = [x - laser_time for x in licks_R]
    plt.plot(licks_L, ys_L,'|',color = 'b')
    plt.plot(licks_R, ys_R,'|',color = 'r')

plt.show()

# %%
merged_data
# Out:
#      missed  laser  choice  free  resp_start_ts  reward_ts  laser_stim_ts  \
# 0         1      1       0     0           7450          0           7113
# 1         1     -1       0     0          10983          0          10646
# 2         1     -1       0     0          14409          0          14074
# 3         1     -1       0     0          18005          0          17668
# 4         1      0       0     0          21550          0          21212
# ..      ...    ...     ...   ...            ...        ...            ...
# 395       0      0      -1     0        1564043    1564417        1563704
# 396       0      0       1     0        1568486    1568815        1568141
# 397       1      1       0     0        1572831          0        1572497
# 398       1      1       0     0        1576346          0        1575997
# 399       0      0       1     0        1579815    1579876        1579481
#
#      end_trial  num_licks_L  num_licks_R  lick_time lick_side
# 0      10646.0            0            0        NaN       NaN
# 1      14074.0            0            0        NaN       NaN
# 2      17668.0            0            0        NaN       NaN
# 3      21212.0            0            0        NaN       NaN
# 4      24747.0            0            0        NaN       NaN
# ..         ...          ...          ...        ...       ...
# 395  1568141.0            2            2        NaN       NaN
# 396  1572497.0            1            2        NaN       NaN
# 397  1575997.0            0            0        NaN       NaN
# 398  1579481.0            0            0        NaN       NaN
# 399  1585481.0            1            1        NaN       NaN
#
# [400 rows x 12 columns]

# %%
# Assuming 'data', 'data_licks_L', and 'data_licks_R' are your DataFrames
# and 'laser' is the column with laser types in 'data'

# Combine left and right licks into one DataFrame
data_licks_L['lick_side'] = 'Left'
data_licks_R['lick_side'] = 'Right'
combined_licks = pd.concat([data_licks_L.rename(columns={0: 'lick_time'}), 
                            data_licks_R.rename(columns={0: 'lick_time'})])

# Merge lick data with laser data based on your time criteria
# Adjust the time criteria as needed
merged_data = pd.merge(data, combined_licks, how='left', 
                       left_on='laser_stim_ts', right_on='lick_time')

# Filter licks for each laser type and plot histograms
laser_types = data['laser'].unique()
for laser_type in laser_types:
    filtered_licks = merged_data[merged_data['laser'] == laser_type]['lick_time']
    plt.figure()
    plt.hist(filtered_licks, bins=20, alpha=0.7, label=f'Laser Type {laser_type}')
    plt.xlabel('Lick Time')
    plt.ylabel('Frequency')
    plt.title(f'Histogram of Lick Times for Laser Type {laser_type}')
    plt.legend()
    plt.show()
# Out:
# D:\programs\anaconda\envs\caiman\lib\site-packages\matplotlib\axes\_axes.py:6831: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# D:\programs\anaconda\envs\caiman\lib\site-packages\matplotlib\axes\_axes.py:6832: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 20
#      18 filtered_licks = merged_data[merged_data['laser'] == laser_type]['lick_time']
#      19 plt.figure()
# ---> 20 plt.hist(filtered_licks, bins=20, alpha=0.7, label=f'Laser Type {laser_type}')
#      21 plt.xlabel('Lick Time')
#      22 plt.ylabel('Frequency')
#
# File D:\programs\anaconda\envs\caiman\lib\site-packages\matplotlib\pyplot.py:3224, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3199 @_copy_docstring_and_deprecators(Axes.hist)
#    3200 def hist(
#    3201     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    3222     BarContainer | Polygon | list[BarContainer | Polygon],
#    3223 ]:
# -> 3224     return gca().hist(
#    3225         x,
#    3226         bins=bins,
#    3227         range=range,
#    3228         density=density,
#    3229         weights=weights,
#    3230         cumulative=cumulative,
#    3231         bottom=bottom,
#    3232         histtype=histtype,
#    3233         align=align,
#    3234         orientation=orientation,
#    3235         rwidth=rwidth,
#    3236         log=log,
#    3237         color=color,
#    3238         label=label,
#    3239         stacked=stacked,
#    3240         **({"data": data} if data is not None else {}),
#    3241         **kwargs,
#    3242     )
#
# File D:\programs\anaconda\envs\caiman\lib\site-packages\matplotlib\__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File D:\programs\anaconda\envs\caiman\lib\site-packages\matplotlib\axes\_axes.py:6859, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6855 # Loop through datasets
#    6856 for i in range(nx):
#    6857     # this will automatically overwrite bins,
#    6858     # so that each histogram uses the same bins
# -> 6859     m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6860     tops.append(m)
#    6861 tops = np.array(tops, float)  # causes problems later if it's an int
#
# File D:\programs\anaconda\envs\caiman\lib\site-packages\numpy\lib\histograms.py:780, in histogram(a, bins, range, density, weights)
#     680 r"""
#     681 Compute the histogram of a dataset.
#     682
#    (...)
#     776
#     777 """
#     778 a, weights = _ravel_and_check_weights(a, weights)
# --> 780 bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     782 # Histogram is an integer or a float array depending on the weights.
#     783 if weights is None:
#
# File D:\programs\anaconda\envs\caiman\lib\site-packages\numpy\lib\histograms.py:426, in _get_bin_edges(a, bins, range, weights)
#     423     if n_equal_bins < 1:
#     424         raise ValueError('`bins` must be positive, when an integer')
# --> 426     first_edge, last_edge = _get_outer_edges(a, range)
#     428 elif np.ndim(bins) == 1:
#     429     bin_edges = np.asarray(bins)
#
# File D:\programs\anaconda\envs\caiman\lib\site-packages\numpy\lib\histograms.py:323, in _get_outer_edges(a, range)
#     321     first_edge, last_edge = a.min(), a.max()
#     322     if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
# --> 323         raise ValueError(
#     324             "autodetected range of [{}, {}] is not finite".format(first_edge, last_edge))
#     326 # expand empty range to avoid divide by zero
#     327 if first_edge == last_edge:
#
# ValueError: autodetected range of [nan, nan] is not finite

# %%
xx=[2,5,1]
xxx = [5,2,7,5,5]
plt.plot(xxx)
plt.plot(xx)
plt.show()

# %%
a = [x - laser_time for x in licks_L]
a
# Out:
# [-7113.0]

# %%
len(licks_L)
# Out:
# 0

# %%
left_after_left = []
left_after_right = []
# compare left after left and lefty after right
for n in np.arange(data.shape[0]-1):
    prev_right =  data['right_correct'][n]
    curr_left = data['left_correct'][n+1]
    if not math.isnan(curr_left):
        if not math.isnan(prev_right):
            left_after_right.append(curr_left)
        else:
            left_after_left.append(curr_left)

# %%
right_after_left = []
right_after_right = []
left_after_left = []
left_after_right = []
# compare left after left and lefty after right
for n in np.arange(data.shape[0]-1):
    prev_left =  data['left_correct'][n]
    curr_right = data['right_correct'][n+1]
    if not math.isnan(curr_right):
        if not math.isnan(prev_left):
            right_after_left.append(curr_right)
        else:
            right_after_right.append(curr_right)
    else:
        if not math.isnan(prev_left):
            right_after_left.append(curr_right)
        else:
            right_after_right.append(curr_right)

# %%
np.mean(left_after_left)

# %%
np.mean(left_after_right)
